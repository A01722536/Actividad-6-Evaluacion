# %%
import A01722536_funciones as fun

# %%
funcion_1=fun.funcion_1("Mallorca.xlsx")
funcion_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16867 entries, 0 to 16866
# Data columns (total 50 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              16867 non-null  int64
#  1   scrape_id                       16867 non-null  int64
#  2   last_scraped                    16867 non-null  datetime64[ns]
#  3   source                          16867 non-null  object
#  4   name                            16867 non-null  object
#  5   host_id                         16867 non-null  int64
#  6   host_name                       16867 non-null  object
#  7   host_since                      16867 non-null  datetime64[ns]
#  8   host_location                   12340 non-null  object
#  9   host_response_time              15434 non-null  object
#  10  host_response_rate              15434 non-null  float64
#  11  host_acceptance_rate            16205 non-null  float64
# ...

# %%
funcion_2=fun.funcion_2(funcion_1)
funcion_2
# Out:
#              id     scrape_id     host_id  host_response_rate  \
# 0       69998.0  2.024121e+13    353156.0                 1.0
# 2      159218.0  2.024121e+13    763897.0                 1.0
# 4      166820.0  2.024121e+13    794829.0                 1.0
# 6      193426.0  2.024121e+13  95323653.0                 1.0
# 8      233901.0  2.024121e+13   1224723.0                 1.0
# ...         ...           ...         ...                 ...
# 16857       NaN           NaN         NaN                 NaN
# 16859       NaN           NaN         NaN                 NaN
# 16861       NaN           NaN         NaN                 NaN
# 16863       NaN           NaN         NaN                 NaN
# 16865       NaN           NaN         NaN                 NaN
#
#        host_acceptance_rate  host_listings_count  host_total_listings_count  \
# 0                      0.91                  2.0                        5.0
# ...

# %%
funcion_3=fun.funcion_3(funcion_1)
funcion_3
# Out:
# Por Columna:
#            id                                    0
# scrape_id                             0
# last_scraped                          0
# source                                0
# name                                  0
# host_id                               0
# host_name                             0
# host_since                            0
# host_location                      4527
# host_response_time                 1433
# host_response_rate                 1433
# host_acceptance_rate                662
# host_is_superhost                   181
# host_listings_count                   0
# host_total_listings_count             0
# host_verifications                    0
# host_has_profile_pic                  0
# host_identity_verified                0
# neighbourhood                     10466
# neighbourhood_cleansed                0
# neighbourhood_group_cleansed      16867
# latitude                              0
# longitude                             0
# ...

# %%
funcion_4=fun.funcion_4(funcion_1)
funcion_4
# Out:
#       last_scraped       source  \
# 0       2024-12-15  city scrape
# 1       2024-12-15  city scrape
# 2       2024-12-15  city scrape
# 3       2024-12-15  city scrape
# 4       2024-12-15  city scrape
# ...            ...          ...
# 16862   2024-12-15  city scrape
# 16863   2024-12-15  city scrape
# 16864   2024-12-15  city scrape
# 16865   2024-12-15  city scrape
# 16866   2024-12-15  city scrape
#
#                                                     name host_name host_since  \
# 0                      COZY HIDEAWAY  LOFT... MI AMOR...       Lor 2011-01-19
# 1                      Villa with a big pool in Mallorca     Xisco 2011-05-02
# 2                           Farmhouse in Nature -ET-3025   Gabriel 2011-06-30
# 3          Corazón de Palma-Habitación con baño privado.     Maria 2011-07-07
# 4      Guest House with Great sea views - Principal Room      Toni 2011-07-08
# ...                                                  ...       ...        ...
# ...
